# %% [markdown]
# # 03 - Forensic Profile
#
# Notebook reserve au Module 3 de KANEA.
#
# Objectif documente : preparer les donnees craniometriques et post-craniennes, integrer les composantes AIMs si disponibles, puis exporter `models/machine_learning/forensic_model.pkl`.
