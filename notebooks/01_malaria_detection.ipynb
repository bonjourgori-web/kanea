# %% [markdown]
# # 01 - Malaria Detection
#
# Notebook reserve au Module 1 de KANEA.
#
# Objectif documente : entrainer un modele `ResNet34` avec `fast.ai v2 + PyTorch` sur le dataset NIH Cell Image Library, puis exporter `models/deep_learning/malaria_model.pkl`.
