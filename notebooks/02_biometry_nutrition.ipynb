# %% [markdown]
# # 02 - Biometry Nutrition
#
# Notebook reserve au Module 2 de KANEA.
#
# Objectif documente : calculer les features anthropometriques, entrainer `RandomForest` et `XGBoost`, puis exporter `models/machine_learning/nutrition_model.pkl`.
