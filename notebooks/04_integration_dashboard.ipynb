# %% [markdown]
# # 04 - Integration Dashboard
#
# Notebook reserve au Module 4 de KANEA.
#
# Objectif documente : integrer les trois modules autour de `multibio_predict()` et preparer la logique du dashboard Streamlit.
